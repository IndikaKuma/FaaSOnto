# %%
import requests
import re
from bs4 import BeautifulSoup
import spacy
import json
import pandas as pd

# %% [markdown]
# ## RSS Feeds

# %%
gcp_url = 'https://cloud.google.com/feeds/functions-release-notes.xml'
azure_url = "https://azurecomcdn.azureedge.net/nl-nl/updates/feed/"
aws_url = "https://docs.aws.amazon.com/lambda/latest/dg/lambda-updates.rss"

# %% [markdown]
# ## Classname data

# %%
with open('query_output.json') as json_file:
    neptune_data = json.load(json_file)

# %%
prefix = "http://www.semanticweb.org/stijn/ontologies/2022/4/faasdss#"
aws_s2 = {c['comment']['value'] :c['s2']['value'].replace(prefix, '')for c in neptune_data['results']['bindings']}

# %%
nlp = spacy.load("en_core_web_md")

# %%
aws_s2_nlp = [nlp(s2) for s2 in aws_s2]

# %%
# aws_s2.values()

# %% [markdown]
# ## Parsing Lambda

# %%
response = requests.get(aws_url)
aws_soup = BeautifulSoup(response.content, features='xml')

# %%
"""Takes description and returns relevant section""" 

CLEANR = re.compile('<.*?>') 
CORE_FINDER = re.compile('(?<=Lambda now supports)(.*)(?=\.\s)')

def parse_item(raw_html):
    cleantext = re.sub(CLEANR, '', raw_html)
    try:
        coretext = re.search(CORE_FINDER,cleantext).group(0)
    except:
        coretext = cleantext
    return coretext

# %%
"""Finds similarities between input and all classes
    Returns top 3 including score""" 

def find_similar_classes(word):
    doc1 = nlp(word)
    sims = {}
    for doc2 in aws_s2_nlp:
        sims[(doc1, doc2)] = doc1.similarity(doc2)
    top_scores = sorted(sims.values(), reverse=True)[:3]
    top_sims = [{aws_s2[str(key[1])]:value} for key,value in sims.items() if value in top_scores]
    return top_sims

# %%
aws_soup.find_all(['item'])[:15]
# Out:
# [<item>
#  <title>Node.js 16 runtime</title>
#  <link>https://docs.aws.amazon.com/lambda/latest/dg/programming-model.html?icmpid=docs_lambda_rss</link>
#  <description>Lambda now supports a new runtime for Node.js 16. Node.js 16 uses Amazon Linux 2. For details, see &lt;a href="https://docs.aws.amazon.com/lambda/latest/dg/programming-model.html?icmpid=docs_lambda_rss"&gt;Building Lambda functions with
#              Node.js&lt;/a&gt;.</description>
#  <pubDate>Wed, 11 May 2022 19:00:00 GMT</pubDate>
#  <guid isPermaLink="false">https://docs.aws.amazon.com/lambda/latest/dg/#Node.js_16_runtime_2022-05-11</guid>
#  </item>,
#  <item>
#  <title>Lambda function URLs</title>
#  <link>https://docs.aws.amazon.com/lambda/latest/dg/lambda-urls.html?icmpid=docs_lambda_rss</link>
#  <description>Lambda now supports function URLs, which are dedicated HTTP(S) endpoints for Lambda functions. For details, see &lt;a href="https://docs.aws.amazon.com/lambda/latest/dg/lambda-urls.html?icmpid=docs_lambda_rss"&gt;Lambda function URLs&lt;/a&gt;.</description>
#  <pubDate>Wed, 6 Apr 2022 19:00:00 GMT</pubDate>
#  <guid isPermaLink="false">https://docs.aws.amazon.com/lambda/latest/dg/#Lambda_function_URLs_2022-04-06</guid>
#  </item>,
#  <item>
#  <title>Shared test events in the AWS Lambda console</title>
#  <link>https://docs.aws.amazon.com/lambda/latest/dg/testing-functions.html?icmpid=docs_lambda_rss</link>
#  <description>Lambda now supports sharing test events with other IAM users in the same AWS account. For details, see &lt;a href="https://docs.aws.amazon.com/lambda/latest/dg/testing-functions.html?icmpid=docs_lambda_rss"&gt;Testing Lambda functions in the console&lt;/a&gt;.</description>
#  <pubDate>Wed, 16 Mar 2022 19:00:00 GMT</pubDate>
#  <guid isPermaLink="false">https://docs.aws.amazon.com/lambda/latest/dg/#Shared_test_events_in_the_AWS_Lambda_console_2022-03-16</guid>
#  </item>,
#  <item>
#  <title>PrincipalOrgId in resource-based policies</title>
#  <link>https://docs.aws.amazon.com/lambda/latest/dg/access-control-resource-based.html?icmpid=docs_lambda_rss</link>
#  <description>Lambda now supports granting permissions to an organization in AWS Organizations. For details, see &lt;a href="https://docs.aws.amazon.com/lambda/latest/dg/access-control-resource-based.html?icmpid=docs_lambda_rss"&gt;Using resource-based policies for AWS Lambda&lt;/a&gt;.</description>
#  <pubDate>Fri, 11 Mar 2022 19:00:00 GMT</pubDate>
#  <guid isPermaLink="false">https://docs.aws.amazon.com/lambda/latest/dg/#PrincipalOrgId_in_resource-based_policies_2022-03-11</guid>
#  </item>,
#  <item>
#  <title>.NET 6 runtime</title>
#  <link>https://docs.aws.amazon.com/lambda/latest/dg/lambda-runtimes.html?icmpid=docs_lambda_rss</link>
#  <description>Lambda now supports a new runtime for .NET 6. For details, see &lt;a href="https://docs.aws.amazon.com/lambda/latest/dg/lambda-runtimes.html?icmpid=docs_lambda_rss"&gt;Lambda runtimes&lt;/a&gt;.</description>
#  <pubDate>Wed, 23 Feb 2022 19:00:00 GMT</pubDate>
#  <guid isPermaLink="false">https://docs.aws.amazon.com/lambda/latest/dg/#.NET_6_runtime_2022-02-23</guid>
#  </item>,
#  <item>
#  <title>Event filtering for Kinesis, DynamoDB, and Amazon SQS event sources</title>
#  <link>https://docs.aws.amazon.com/lambda/latest/dg/invocation-eventfiltering.html?icmpid=docs_lambda_rss</link>
#  <description>Lambda now supports event filtering for Kinesis, DynamoDB, and Amazon SQS event sources. For details, see &lt;a href="https://docs.aws.amazon.com/lambda/latest/dg/invocation-eventfiltering.html?icmpid=docs_lambda_rss"&gt;Lambda event filtering&lt;/a&gt;.</description>
#  <pubDate>Wed, 24 Nov 2021 19:00:00 GMT</pubDate>
#  <guid isPermaLink="false">https://docs.aws.amazon.com/lambda/latest/dg/#Event_filtering_for_Kinesis,_DynamoDB,_and_Amazon_SQS_event_sources_2021-11-24</guid>
#  </item>,
#  <item>
#  <title>mTLS authentication for Amazon MSK and self-managed Apache Kafka event sources</title>
#  <link>https://docs.aws.amazon.com/lambda/latest/dg/with-msk.html?icmpid=docs_lambda_rss</link>
#  <description>Lambda now supports mTLS authentication for Amazon MSK and self-managed Apache Kafka event sources. For details, see &lt;a href="https://docs.aws.amazon.com/lambda/latest/dg/with-msk.html?icmpid=docs_lambda_rss"&gt;Using Lambda with Amazon MSK&lt;/a&gt;.</description>
#  <pubDate>Fri, 19 Nov 2021 19:00:00 GMT</pubDate>
#  <guid isPermaLink="false">https://docs.aws.amazon.com/lambda/latest/dg/#mTLS_authentication_for_Amazon_MSK_and_self-managed_Apache_Kafka_event_sources_2021-11-19</guid>
#  </item>,
#  <item>
#  <title>Lambda on Graviton2</title>
#  <link>https://docs.aws.amazon.com/lambda/latest/dg/foundation-arch.html?icmpid=docs_lambda_rss</link>
#  <description>Lambda now supports Graviton2 for functions using arm64 architecture. For details, see &lt;a href="https://docs.aws.amazon.com/lambda/latest/dg/foundation-arch.html?icmpid=docs_lambda_rss"&gt;Lambda instruction set architectures&lt;/a&gt;.</description>
#  <pubDate>Wed, 29 Sep 2021 19:00:00 GMT</pubDate>
#  <guid isPermaLink="false">https://docs.aws.amazon.com/lambda/latest/dg/#Lambda_on_Graviton2_2021-09-29</guid>
#  </item>,
#  <item>
#  <title>Python 3.9 runtime</title>
#  <link>https://docs.aws.amazon.com/lambda/latest/dg/lambda-runtimes.html?icmpid=docs_lambda_rss</link>
#  <description>Lambda now supports a new runtime for Python 3.9. For details, see &lt;a href="https://docs.aws.amazon.com/lambda/latest/dg/lambda-runtimes.html?icmpid=docs_lambda_rss"&gt;Lambda runtimes&lt;/a&gt;.</description>
#  <pubDate>Mon, 16 Aug 2021 19:00:00 GMT</pubDate>
#  <guid isPermaLink="false">https://docs.aws.amazon.com/lambda/latest/dg/#Python_3.9_runtime_2021-08-16</guid>
#  </item>,
#  <item>
#  <title>New runtime versions for Node.js, Python, and Java</title>
#  <link>https://docs.aws.amazon.com/lambda/latest/dg/lambda-runtimes.html?icmpid=docs_lambda_rss</link>
#  <description>New runtime versions are available for Node.js, Python, and Java. For details, see &lt;a href="https://docs.aws.amazon.com/lambda/latest/dg/lambda-runtimes.html?icmpid=docs_lambda_rss"&gt;Lambda runtimes&lt;/a&gt;.</description>
#  <pubDate>Wed, 21 Jul 2021 19:00:00 GMT</pubDate>
#  <guid isPermaLink="false">https://docs.aws.amazon.com/lambda/latest/dg/#New_runtime_versions_for_Node.js,_Python,_and_Java_2021-07-21</guid>
#  </item>,
#  <item>
#  <title>Support for RabbitMQ as an event source on Lambda</title>
#  <link>https://docs.aws.amazon.com/lambda/latest/dg/with-mq.html?icmpid=docs_lambda_rss</link>
#  <description>Lambda now supports Amazon MQ for RabbitMQ as an event source.
#            Amazon MQ is a managed message broker service for Apache ActiveMQ and RabbitMQ
#            that makes it easy to set up and operate message brokers in the cloud.
#            For details, see &lt;a href="https://docs.aws.amazon.com/lambda/latest/dg/with-mq.html?icmpid=docs_lambda_rss"&gt;Using Lambda with Amazon MQ&lt;/a&gt;.</description>
#  <pubDate>Wed, 7 Jul 2021 19:00:00 GMT</pubDate>
#  <guid isPermaLink="false">https://docs.aws.amazon.com/lambda/latest/dg/#Support_for_RabbitMQ_as_an_event_source_on_Lambda_2021-07-07</guid>
#  </item>,
#  <item>
#  <title>SASL/PLAIN authentication for self-managed Kafka on Lambda</title>
#  <link>https://docs.aws.amazon.com/lambda/latest/dg/with-kafka.html?icmpid=docs_lambda_rss</link>
#  <description>SASL/PLAIN is now a supported authentication mechanism for self-managed Kafka event sources on Lambda
#            Customers already using SASL/PLAIN on their self-managed Kafka cluster can now easily use Lambda to build
#            consumer applications without having to modify the way they authenticate.
#            For details, see &lt;a href="https://docs.aws.amazon.com/lambda/latest/dg/with-kafka.html?icmpid=docs_lambda_rss"&gt;Using Lambda with self-managed Apache Kafka&lt;/a&gt;.</description>
#  <pubDate>Tue, 29 Jun 2021 19:00:00 GMT</pubDate>
#  <guid isPermaLink="false">https://docs.aws.amazon.com/lambda/latest/dg/#SASL/PLAIN_authentication_for_self-managed_Kafka_on_Lambda_2021-06-29</guid>
#  </item>,
#  <item>
#  <title>Lambda Extensions API</title>
#  <link>https://docs.aws.amazon.com/lambda/latest/dg/runtimes-extensions-api.html?icmpid=docs_lambda_rss</link>
#  <description>General availability for Lambda extensions. Use extensions to augment your Lambda functions. You can use extensions provided by
#            Lambda Partners, or you can create your own Lambda extensions.
#           For details, see &lt;a href="https://docs.aws.amazon.com/lambda/latest/dg/runtimes-extensions-api.html?icmpid=docs_lambda_rss"&gt;Lambda Extensions API&lt;/a&gt;.</description>
#  <pubDate>Mon, 24 May 2021 19:00:00 GMT</pubDate>
#  <guid isPermaLink="false">https://docs.aws.amazon.com/lambda/latest/dg/#Lambda_Extensions_API_2021-05-24</guid>
#  </item>,
#  <item>
#  <title>New Lambda console experience</title>
#  <link>https://docs.aws.amazon.com/lambda/latest/dg/lambda-releases.html</link>
#  <description>The Lambda console has been redesigned to improve performance and consistency. </description>
#  <pubDate>Tue, 2 Mar 2021 19:00:00 GMT</pubDate>
#  <guid isPermaLink="false">https://docs.aws.amazon.com/lambda/latest/dg/#New_Lambda_console_experience_2021-03-02</guid>
#  </item>,
#  <item>
#  <title>Node.js 14 runtime</title>
#  <link>https://docs.aws.amazon.com/lambda/latest/dg/programming-model.html?icmpid=docs_lambda_rss</link>
#  <description>Lambda now supports a new runtime for Node.js 14. Node.js 14 uses Amazon Linux 2. For details, see &lt;a href="https://docs.aws.amazon.com/lambda/latest/dg/programming-model.html?icmpid=docs_lambda_rss"&gt;Building Lambda functions with
#              Node.js&lt;/a&gt;.</description>
#  <pubDate>Wed, 27 Jan 2021 19:00:00 GMT</pubDate>
#  <guid isPermaLink="false">https://docs.aws.amazon.com/lambda/latest/dg/#Node.js_14_runtime_2021-01-27</guid>
#  </item>]

# %%
NAMESPACE = 'faas:'
platform = 'AWSLambda'
triple_suggestions = []
for item in aws_soup.find_all(['item'])[:15]:
    ref = item.link.text
    date = item.pubDate.text
    title = item.title.text
    description = item.description.text

    # strip for core
    parsed_description = parse_item(description)
    # spacy magic
    doc = nlp(parsed_description)
    sims = find_similar_classes(parsed_description)
    
    data = []
    for token in doc:
        token_data = {"token": token.text, "pos": token.pos_}
        data.append(token_data)
    
    # All Propn's are candidate features
    candidate_features = [token['token'] for token in data  if token['pos'] == 'PROPN']
    
    triple_suggestions.append({"Title": title, "Description": description, "Parsed Description": parsed_description, 
                               "Date": date, "Reference": ref, "Superclass Suggestions": sims, 
                               "Feature Suggestions": candidate_features}
    )
# Out:
# <ipython-input-32-47b2d837da5a>:9: UserWarning: [W008] Evaluating Doc.similarity based on empty vectors.
#   sims[(doc1, doc2)] = doc1.similarity(doc2)

# %%
df = pd.DataFrame.from_records(triple_suggestions)

# %%
df = df[df['Description'].str.startswith('Lambda now supports')]

# %%
df
# Out:
#                                                 Title  \
# 0                                  Node.js 16 runtime
# 1                                Lambda function URLs
# 2        Shared test events in the AWS Lambda console
# 3           PrincipalOrgId in resource-based policies
# 4                                      .NET 6 runtime
# 5   Event filtering for Kinesis, DynamoDB, and Ama...
# 6   mTLS authentication for Amazon MSK and self-ma...
# 7                                 Lambda on Graviton2
# 8                                  Python 3.9 runtime
# 10  Support for RabbitMQ as an event source on Lambda
# 14                                 Node.js 14 runtime
#
#                                           Description  \
# 0   Lambda now supports a new runtime for Node.js ...
# 1   Lambda now supports function URLs, which are d...
# 2   Lambda now supports sharing test events with o...
# 3   Lambda now supports granting permissions to an...
# 4   Lambda now supports a new runtime for .NET 6. ...
# 5   Lambda now supports event filtering for Kinesi...
# 6   Lambda now supports mTLS authentication for Am...
# 7   Lambda now supports Graviton2 for functions us...
# 8   Lambda now supports a new runtime for Python 3...
# 10  Lambda now supports Amazon MQ for RabbitMQ as ...
# 14  Lambda now supports a new runtime for Node.js ...
#
#                                    Parsed Description  \
# 0    a new runtime for Node.js 16. Node.js 16 uses...
# 1    function URLs, which are dedicated HTTP(S) en...
# 2    sharing test events with other IAM users in t...
# 3    granting permissions to an organization in AW...
# 4                            a new runtime for .NET 6
# 5    event filtering for Kinesis, DynamoDB, and Am...
# 6    mTLS authentication for Amazon MSK and self-m...
# 7    Graviton2 for functions using arm64 architecture
# 8                        a new runtime for Python 3.9
# 10          Amazon MQ for RabbitMQ as an event source
# 14   a new runtime for Node.js 14. Node.js 14 uses...
#
#                              Date  \
# 0   Wed, 11 May 2022 19:00:00 GMT
# 1    Wed, 6 Apr 2022 19:00:00 GMT
# 2   Wed, 16 Mar 2022 19:00:00 GMT
# 3   Fri, 11 Mar 2022 19:00:00 GMT
# 4   Wed, 23 Feb 2022 19:00:00 GMT
# 5   Wed, 24 Nov 2021 19:00:00 GMT
# 6   Fri, 19 Nov 2021 19:00:00 GMT
# 7   Wed, 29 Sep 2021 19:00:00 GMT
# 8   Mon, 16 Aug 2021 19:00:00 GMT
# 10   Wed, 7 Jul 2021 19:00:00 GMT
# 14  Wed, 27 Jan 2021 19:00:00 GMT
#
#                                             Reference  \
# 0   https://docs.aws.amazon.com/lambda/latest/dg/p...
# 1   https://docs.aws.amazon.com/lambda/latest/dg/l...
# 2   https://docs.aws.amazon.com/lambda/latest/dg/t...
# 3   https://docs.aws.amazon.com/lambda/latest/dg/a...
# 4   https://docs.aws.amazon.com/lambda/latest/dg/l...
# 5   https://docs.aws.amazon.com/lambda/latest/dg/i...
# 6   https://docs.aws.amazon.com/lambda/latest/dg/w...
# 7   https://docs.aws.amazon.com/lambda/latest/dg/f...
# 8   https://docs.aws.amazon.com/lambda/latest/dg/l...
# 10  https://docs.aws.amazon.com/lambda/latest/dg/w...
# 14  https://docs.aws.amazon.com/lambda/latest/dg/p...
#
#                                Superclass Suggestions  \
# 0   [{'CICDPipelining': 0.741988389149947}, {'Runt...
# 1   [{'FunctionMarketplace': 0.8937052898719214}, ...
# 2   [{'LicenseType': 0.8267513541347121}, {'Platfo...
# 3   [{'LicenseType': 0.822717907973031}, {'Functio...
# 4   [{'LicenseType': 0.7477392604822207}, {'Client...
# 5   [{'DeploymentMethods': 0.7504138202538165}, {'...
# 6   [{'CICDPipelining': 0.6830321168077201}, {'Dep...
# 7   [{'StreamProcessingPlatform': 0.80830392578667...
# 8   [{'CICDPipelining': 0.7235304447209447}, {'Run...
# 10  [{'EventSourceIntegration': 0.682830762122754}...
# 14  [{'CICDPipelining': 0.741988389149947}, {'Runt...
#
#                    Feature Suggestions
# 0    [Node.js, Node.js, Amazon, Linux]
# 1                     [HTTP(S, Lambda]
# 2                           [IAM, AWS]
# 3                                [AWS]
# 4                                   []
# 5     [Kinesis, DynamoDB, Amazon, SQS]
# 6   [mTLS, Amazon, MSK, Apache, Kafka]
# 7                              [arm64]
# 8                             [Python]
# 10              [Amazon, MQ, RabbitMQ]
# 14   [Node.js, Node.js, Amazon, Linux]

# %%
df.to_csv('DSS/results.csv')
